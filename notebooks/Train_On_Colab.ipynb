# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
# Example: path_to_project = '/content/drive/MyDrive/SpeechEnhancementProject'
path_to_project = '/content/drive/MyDrive/SpeechEnhancementProject' 
os.chdir(path_to_project)

# Kiểm tra lại các file hiện hành
# !ls

# %%
# !nvidia-smi

# %%
# !python train.py --config config/waveunet.yaml

# %%
# !python train.py --config config/dccrn.yaml
